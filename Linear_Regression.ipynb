# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %matplotlib inline

# %%
df_pl=pd.read_csv('final_data.csv')

# %%
df_pl.head(2)
# Out:
#                                 player               team          name  \
# 0   /david-de-gea/profil/spieler/59377  Manchester United  David de Gea
# 1  /jack-butland/profil/spieler/128899  Manchester United  Jack Butland
#
#      position  height   age  appearance  goals  assists  yellow cards  ...  \
# 0  Goalkeeper   189.0  32.0         104    0.0      0.0      0.009585  ...
# 1  Goalkeeper   196.0  30.0          15    0.0      0.0      0.069018  ...
#
#    goals conceded  clean sheets  minutes played  days_injured  games_injured  \
# 0        1.217252      0.335463            9390            42              5
# 1        1.242331      0.207055            1304           510             58
#
#    award  current_value  highest_value  position_encoded  winger
# 0     13       15000000       70000000                 1       0
# 1      1        1500000       22000000                 1       0
#
# [2 rows x 22 columns]

# %%
df_pl.duplicated().sum()
# Out:
# 0

# %%
df_pl.isnull().sum()
# Out:
# player                 0
# team                   0
# name                   0
# position               0
# height                 0
# age                    0
# appearance             0
# goals                  0
# assists                0
# yellow cards           0
# second yellow cards    0
# red cards              0
# goals conceded         0
# clean sheets           0
# minutes played         0
# days_injured           0
# games_injured          0
# award                  0
# current_value          0
# highest_value          0
# position_encoded       0
# winger                 0
# dtype: int64

# %%
df_pl.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
df_pl=df_pl.drop(['player'], axis=1)

# %%
df_pl.head(2)
# Out:
#                 team          name    position  height   age  appearance  \
# 0  Manchester United  David de Gea  Goalkeeper   189.0  32.0         104
# 1  Manchester United  Jack Butland  Goalkeeper   196.0  30.0          15
#
#    goals  assists  yellow cards  second yellow cards  ...  goals conceded  \
# 0    0.0      0.0      0.009585                  0.0  ...        1.217252
# 1    0.0      0.0      0.069018                  0.0  ...        1.242331
#
#    clean sheets  minutes played  days_injured  games_injured  award  \
# 0      0.335463            9390            42              5     13
# 1      0.207055            1304           510             58      1
#
#    current_value  highest_value  position_encoded  winger
# 0       15000000       70000000                 1       0
# 1        1500000       22000000                 1       0
#
# [2 rows x 21 columns]

# %%
df_pl.sort_values(by='highest_value' , ascending=False).head()
# Out:
#                      team             name               position  height  \
# 2644  Paris Saint-Germain    Kylian Mbappé  Attack Centre-Forward   178.0
# 2643  Paris Saint-Germain     Lionel Messi     Attack-RightWinger   170.0
# 2642  Paris Saint-Germain           Neymar      Attack-LeftWinger   175.0
# 453       Manchester City   Erling Haaland  Attack Centre-Forward   195.0
# 527            Chelsea FC  Raheem Sterling      Attack-LeftWinger   170.0
#
#        age  appearance     goals   assists  yellow cards  second yellow cards  \
# 2644  24.0          89  0.963082  0.433387      0.204655              0.00000
# 2643  35.0          75  0.442464  0.483945      0.013827              0.00000
# 2642  31.0          57  0.594883  0.479744      0.383795              0.01919
# 453   22.0          83  1.118270  0.234699      0.124252              0.00000
# 527   28.0          85  0.414233  0.207116      0.111524              0.00000
#
#       ...  goals conceded  clean sheets  minutes played  days_injured  \
# 2644  ...             0.0           0.0            7476           139
# 2643  ...             0.0           0.0            6509           167
# 2642  ...             0.0           0.0            4690           419
# 453   ...             0.0           0.0            6519           204
# 527   ...             0.0           0.0            5649           284
#
#       games_injured  award  current_value  highest_value  position_encoded  \
# 2644             23     37      180000000      200000000                 4
# 2643             30     92       45000000      180000000                 4
# 2642             67     35       70000000      180000000                 4
# 453              36     17      170000000      170000000                 4
# 527              34     13       60000000      160000000                 4
#
#       winger
# 2644       0
# 2643       1
# 2642       1
# 453        0
# 527        1
#
# [5 rows x 21 columns]

# %%
df_pl.dtypes
# Out:
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
categorical_features=['team','name','position']
numeric_features=['position',  'height',  'age' , 'appearance' ,'goals',  'assists',  'yellow', 'cards', 'second', 'yellow cards',
 'red cards',  'goals conceded' ,'clean sheet', 'minutes played' ,'days_injured',  'games_injured'  , 'award' ,'current_value',
 'highest_value' , 'position_encoded' ,'winger' ]

# %%
df_pl1 = df_pl[(df_pl['highest_value'] <= 100000000) & (df_pl['highest_value'] >= 20000000)]['highest_value']

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl1, bins=40)                         
plt.xlabel('Highest Value')
plt.ylabel('Frequency')
plt.title('Histogram of Highest Values')
plt.show()

# %%
df_pl=df_pl[(df_pl['highest_value'] <= 100000000) & (df_pl['highest_value'] >= 20000000)]

# %%
df_pl
# Out:
#                            team                 name  \
# 0             Manchester United         David de Gea
# 1             Manchester United         Jack Butland
# 3             Manchester United    Lisandro Martínez
# 4             Manchester United       Raphaël Varane
# 5             Manchester United        Harry Maguire
# ...                         ...                  ...
# 9423                Al-Nassr FC         Luiz Gustavo
# 9427                Al-Nassr FC              Talisca
# 9428                Al-Nassr FC        Pity Martínez
# 10453         Melbourne Victory                 Nani
# 10736  Western Sydney Wanderers  Morgan Schneiderlin
#
#                          position  height   age  appearance     goals  \
# 0                      Goalkeeper   189.0  32.0         104  0.000000
# 1                      Goalkeeper   196.0  30.0          15  0.000000
# 3            Defender Centre-Back   175.0  25.0          82  0.028090
# 4            Defender Centre-Back   191.0  30.0          63  0.017889
# 5            Defender Centre-Back   194.0  30.0          68  0.037799
# ...                           ...     ...   ...         ...       ...
# 9423   midfield-DefensiveMidfield   187.0  35.0          60  0.132576
# 9427   midfield-AttackingMidfield   190.0  29.0          57  0.773639
# 9428   midfield-AttackingMidfield   170.0  29.0          29  0.451128
# 10453           Attack-LeftWinger   177.0  36.0          20  0.000000
# 10736  midfield-DefensiveMidfield   186.0  33.0          36  0.107399
#
#         assists  yellow cards  second yellow cards  ...  goals conceded  \
# 0      0.000000      0.009585               0.0000  ...        1.217252
# 1      0.000000      0.069018               0.0000  ...        1.242331
# 3      0.056180      0.224719               0.0000  ...        0.000000
# 4      0.017889      0.053667               0.0000  ...        0.000000
# 5      0.000000      0.302394               0.0189  ...        0.000000
# ...         ...           ...                  ...  ...             ...
# 9423   0.094697      0.189394               0.0000  ...        0.000000
# 9427   0.073680      0.202620               0.0000  ...        0.000000
# 9428   0.112782      0.281955               0.0000  ...        0.000000
# 10453  0.275510      0.275510               0.0000  ...        0.000000
# 10736  0.107399      0.268496               0.0000  ...        0.000000
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 0          0.335463            9390            42              5     13
# 1          0.207055            1304           510             58      1
# 3          0.000000            6408           175             22      9
# 4          0.000000            5031           238             51     21
# 5          0.000000            4762           148             27      1
# ...             ...             ...           ...            ...    ...
# 9423       0.000000            4752           324             44      7
# 9427       0.000000            4886            93             22     11
# 9428       0.000000            1596           553             56     12
# 10453      0.000000             980           394             57     17
# 10736      0.000000            1676           389             42      5
#
#        current_value  highest_value  position_encoded  winger
# 0           15000000       70000000                 1       0
# 1            1500000       22000000                 1       0
# 3           50000000       50000000                 2       0
# 4           40000000       80000000                 2       0
# 5           25000000       70000000                 2       0
# ...              ...            ...               ...     ...
# 9423          800000       22000000                 3       0
# 9427        15000000       28000000                 3       0
# 9428         7000000       20000000                 3       0
# 10453         500000       36500000                 4       1
# 10736        1500000       30000000                 3       0
#
# [915 rows x 21 columns]

# %%
df_pl.sort_values(by='goals' , ascending=False).head()
# Out:
#                                team                name  \
# 3733  Sociedade Esportiva Palmeiras             Endrick
# 2101                    Juventus FC   Mohamed Ihattaren
# 3765                    CR Flamengo               Pedro
# 1025                  Bayern Munich          Mathys Tel
# 1549                   FC Barcelona  Robert Lewandowski
#
#                         position  height   age  appearance     goals  \
# 3733       Attack Centre-Forward   173.0  16.0           8  1.317073
# 2101  midfield-AttackingMidfield   183.0  21.0           6  1.304348
# 3765       Attack Centre-Forward   185.0  25.0          10  1.119751
# 1025       Attack Centre-Forward   183.0  18.0          46  0.964975
# 1549       Attack Centre-Forward   185.0  34.0          92  0.938442
#
#        assists  yellow cards  second yellow cards  ...  goals conceded  \
# 3733  0.000000      0.439024             0.000000  ...             0.0
# 2101  0.652174      0.000000             0.000000  ...             0.0
# 3765  0.000000      0.139969             0.000000  ...             0.0
# 1025  0.000000      0.128663             0.000000  ...             0.0
# 1549  0.169598      0.067839             0.011307  ...             0.0
#
#       clean sheets  minutes played  days_injured  games_injured  award  \
# 3733           0.0             205             0              0      4
# 2101           0.0             276             0              0      3
# 3765           0.0             643           253             32      7
# 1025           0.0            1399            15              4      2
# 1549           0.0            7960           139             22     65
#
#       current_value  highest_value  position_encoded  winger
# 3733       20000000       20000000                 4       0
# 2101              0       22000000                 3       0
# 3765       22000000       22000000                 4       0
# 1025       20000000       20000000                 4       0
# 1549       30000000       90000000                 4       0
#
# [5 rows x 21 columns]

# %%
Q1 = df_pl['goals'].quantile(0.25)
Q3 = df_pl['goals'].quantile(0.75)
IQR = Q3 - Q1
df_pl2 = df_pl[(df_pl['goals'] >= Q1 - 1.5 * IQR) & (df_pl['goals'] <= Q3 + 1.5 * IQR)]

df_pl2
# Out:
#                            team                 name  \
# 0             Manchester United         David de Gea
# 1             Manchester United         Jack Butland
# 3             Manchester United    Lisandro Martínez
# 4             Manchester United       Raphaël Varane
# 5             Manchester United        Harry Maguire
# ...                         ...                  ...
# 9402          Al-Hilal Saudi FC        Moussa Marega
# 9423                Al-Nassr FC         Luiz Gustavo
# 9428                Al-Nassr FC        Pity Martínez
# 10453         Melbourne Victory                 Nani
# 10736  Western Sydney Wanderers  Morgan Schneiderlin
#
#                          position  height   age  appearance     goals  \
# 0                      Goalkeeper   189.0  32.0         104  0.000000
# 1                      Goalkeeper   196.0  30.0          15  0.000000
# 3            Defender Centre-Back   175.0  25.0          82  0.028090
# 4            Defender Centre-Back   191.0  30.0          63  0.017889
# 5            Defender Centre-Back   194.0  30.0          68  0.037799
# ...                           ...     ...   ...         ...       ...
# 9402           Attack-RightWinger   183.0  32.0          71  0.377668
# 9423   midfield-DefensiveMidfield   187.0  35.0          60  0.132576
# 9428   midfield-AttackingMidfield   170.0  29.0          29  0.451128
# 10453           Attack-LeftWinger   177.0  36.0          20  0.000000
# 10736  midfield-DefensiveMidfield   186.0  33.0          36  0.107399
#
#         assists  yellow cards  second yellow cards  ...  goals conceded  \
# 0      0.000000      0.009585               0.0000  ...        1.217252
# 1      0.000000      0.069018               0.0000  ...        1.242331
# 3      0.056180      0.224719               0.0000  ...        0.000000
# 4      0.017889      0.053667               0.0000  ...        0.000000
# 5      0.000000      0.302394               0.0189  ...        0.000000
# ...         ...           ...                  ...  ...             ...
# 9402   0.098522      0.098522               0.0000  ...        0.000000
# 9423   0.094697      0.189394               0.0000  ...        0.000000
# 9428   0.112782      0.281955               0.0000  ...        0.000000
# 10453  0.275510      0.275510               0.0000  ...        0.000000
# 10736  0.107399      0.268496               0.0000  ...        0.000000
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 0          0.335463            9390            42              5     13
# 1          0.207055            1304           510             58      1
# 3          0.000000            6408           175             22      9
# 4          0.000000            5031           238             51     21
# 5          0.000000            4762           148             27      1
# ...             ...             ...           ...            ...    ...
# 9402       0.000000            5481            84             13      8
# 9423       0.000000            4752           324             44      7
# 9428       0.000000            1596           553             56     12
# 10453      0.000000             980           394             57     17
# 10736      0.000000            1676           389             42      5
#
#        current_value  highest_value  position_encoded  winger
# 0           15000000       70000000                 1       0
# 1            1500000       22000000                 1       0
# 3           50000000       50000000                 2       0
# 4           40000000       80000000                 2       0
# 5           25000000       70000000                 2       0
# ...              ...            ...               ...     ...
# 9402         4000000       30000000                 4       1
# 9423          800000       22000000                 3       0
# 9428         7000000       20000000                 3       0
# 10453         500000       36500000                 4       1
# 10736        1500000       30000000                 3       0
#
# [897 rows x 21 columns]

# %%
Q1 = df_pl['goals'].quantile(0.25)
Q3 = df_pl['goals'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['goals'] >= Q1 - 1.5 * IQR) & (df_pl['goals'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['goals'], bins=40)                         
plt.xlabel('goals')
plt.ylabel('Frequency')
plt.title('Histogram of goals')
plt.show()

# %%
df_pl['current_value'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        15000000
# 1         1500000
# 3        50000000
# 4        40000000
# 5        25000000
#            ...
# 9402      4000000
# 9423       800000
# 9428      7000000
# 10453      500000
# 10736     1500000
# Name: current_value, Length: 897, dtype: int64>

# %%
Q1 = df_pl['current_value'].quantile(0.25)
Q3 = df_pl['current_value'].quantile(0.75)
IQR = Q3 - Q1
df_pl3=df_pl[(df_pl['current_value'] >= Q1 - 1.5 * IQR) & (df_pl['current_value'] <= Q3 + 1.5 * IQR)]
df_pl3
# Out:
#                            team                 name  \
# 0             Manchester United         David de Gea
# 1             Manchester United         Jack Butland
# 3             Manchester United    Lisandro Martínez
# 4             Manchester United       Raphaël Varane
# 5             Manchester United        Harry Maguire
# ...                         ...                  ...
# 9402          Al-Hilal Saudi FC        Moussa Marega
# 9423                Al-Nassr FC         Luiz Gustavo
# 9428                Al-Nassr FC        Pity Martínez
# 10453         Melbourne Victory                 Nani
# 10736  Western Sydney Wanderers  Morgan Schneiderlin
#
#                          position  height   age  appearance     goals  \
# 0                      Goalkeeper   189.0  32.0         104  0.000000
# 1                      Goalkeeper   196.0  30.0          15  0.000000
# 3            Defender Centre-Back   175.0  25.0          82  0.028090
# 4            Defender Centre-Back   191.0  30.0          63  0.017889
# 5            Defender Centre-Back   194.0  30.0          68  0.037799
# ...                           ...     ...   ...         ...       ...
# 9402           Attack-RightWinger   183.0  32.0          71  0.377668
# 9423   midfield-DefensiveMidfield   187.0  35.0          60  0.132576
# 9428   midfield-AttackingMidfield   170.0  29.0          29  0.451128
# 10453           Attack-LeftWinger   177.0  36.0          20  0.000000
# 10736  midfield-DefensiveMidfield   186.0  33.0          36  0.107399
#
#         assists  yellow cards  second yellow cards  ...  goals conceded  \
# 0      0.000000      0.009585               0.0000  ...        1.217252
# 1      0.000000      0.069018               0.0000  ...        1.242331
# 3      0.056180      0.224719               0.0000  ...        0.000000
# 4      0.017889      0.053667               0.0000  ...        0.000000
# 5      0.000000      0.302394               0.0189  ...        0.000000
# ...         ...           ...                  ...  ...             ...
# 9402   0.098522      0.098522               0.0000  ...        0.000000
# 9423   0.094697      0.189394               0.0000  ...        0.000000
# 9428   0.112782      0.281955               0.0000  ...        0.000000
# 10453  0.275510      0.275510               0.0000  ...        0.000000
# 10736  0.107399      0.268496               0.0000  ...        0.000000
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 0          0.335463            9390            42              5     13
# 1          0.207055            1304           510             58      1
# 3          0.000000            6408           175             22      9
# 4          0.000000            5031           238             51     21
# 5          0.000000            4762           148             27      1
# ...             ...             ...           ...            ...    ...
# 9402       0.000000            5481            84             13      8
# 9423       0.000000            4752           324             44      7
# 9428       0.000000            1596           553             56     12
# 10453      0.000000             980           394             57     17
# 10736      0.000000            1676           389             42      5
#
#        current_value  highest_value  position_encoded  winger
# 0           15000000       70000000                 1       0
# 1            1500000       22000000                 1       0
# 3           50000000       50000000                 2       0
# 4           40000000       80000000                 2       0
# 5           25000000       70000000                 2       0
# ...              ...            ...               ...     ...
# 9402         4000000       30000000                 4       1
# 9423          800000       22000000                 3       0
# 9428         7000000       20000000                 3       0
# 10453         500000       36500000                 4       1
# 10736        1500000       30000000                 3       0
#
# [855 rows x 21 columns]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['current_value'], bins=40)                         
plt.xlabel('current_value')
plt.ylabel('Frequency')
plt.title('Histogram of current_value')
plt.show()

# %%
Q1 = df_pl['current_value'].quantile(0.25)
Q3 = df_pl['current_value'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['current_value'] >= Q1 - 1.5 * IQR) & (df_pl['current_value'] <= Q3 + 1.5 * IQR)]

# %%
Q1 = df_pl['age'].quantile(0.25)
Q3 = df_pl['age'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['age'] >= Q1 - 1.5 * IQR) & (df_pl['age'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['age'], bins=40)                         
plt.xlabel('age')
plt.ylabel('Frequency')
plt.title('Histogram of age')
plt.show()

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['assists'], bins=40)                         
plt.xlabel('assists  ')
plt.ylabel('Frequency')
plt.title('Histogram of assists  ')
plt.show()

# %%
Q1 = df_pl['assists'].quantile(0.25)
Q3 = df_pl['assists'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['assists'] >= Q1 - 1.5 * IQR) & (df_pl['assists'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['assists'], bins=40)                         
plt.xlabel('assists  ')
plt.ylabel('Frequency')
plt.title('Histogram of assists  ')
plt.show()

# %%
Q1 = df_pl['height'].quantile(0.25)
Q3 = df_pl['height'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['height'] >= Q1 - 1.5 * IQR) & (df_pl['height'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['height'], bins=40)                         
plt.xlabel('height  ')
plt.ylabel('Frequency')
plt.title('Histogram of height  ')
plt.show()

# %%
Q1 = df_pl['appearance'].quantile(0.25)
Q3 = df_pl['appearance'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['appearance'] >= Q1 - 1.5 * IQR) & (df_pl['appearance'] <= Q3 + 1.5 * IQR)]

# %%
df_pl
# Out:
#                            team                 name  \
# 0             Manchester United         David de Gea
# 3             Manchester United    Lisandro Martínez
# 4             Manchester United       Raphaël Varane
# 5             Manchester United        Harry Maguire
# 6             Manchester United      Victor Lindelöf
# ...                         ...                  ...
# 9402          Al-Hilal Saudi FC        Moussa Marega
# 9423                Al-Nassr FC         Luiz Gustavo
# 9428                Al-Nassr FC        Pity Martínez
# 10453         Melbourne Victory                 Nani
# 10736  Western Sydney Wanderers  Morgan Schneiderlin
#
#                          position  height   age  appearance     goals  \
# 0                      Goalkeeper   189.0  32.0         104  0.000000
# 3            Defender Centre-Back   175.0  25.0          82  0.028090
# 4            Defender Centre-Back   191.0  30.0          63  0.017889
# 5            Defender Centre-Back   194.0  30.0          68  0.037799
# 6            Defender Centre-Back   187.0  28.0          70  0.000000
# ...                           ...     ...   ...         ...       ...
# 9402           Attack-RightWinger   183.0  32.0          71  0.377668
# 9423   midfield-DefensiveMidfield   187.0  35.0          60  0.132576
# 9428   midfield-AttackingMidfield   170.0  29.0          29  0.451128
# 10453           Attack-LeftWinger   177.0  36.0          20  0.000000
# 10736  midfield-DefensiveMidfield   186.0  33.0          36  0.107399
#
#         assists  yellow cards  second yellow cards  ...  goals conceded  \
# 0      0.000000      0.009585               0.0000  ...        1.217252
# 3      0.056180      0.224719               0.0000  ...        0.000000
# 4      0.017889      0.053667               0.0000  ...        0.000000
# 5      0.000000      0.302394               0.0189  ...        0.000000
# 6      0.032901      0.115153               0.0000  ...        0.000000
# ...         ...           ...                  ...  ...             ...
# 9402   0.098522      0.098522               0.0000  ...        0.000000
# 9423   0.094697      0.189394               0.0000  ...        0.000000
# 9428   0.112782      0.281955               0.0000  ...        0.000000
# 10453  0.275510      0.275510               0.0000  ...        0.000000
# 10736  0.107399      0.268496               0.0000  ...        0.000000
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 0          0.335463            9390            42              5     13
# 3          0.000000            6408           175             22      9
# 4          0.000000            5031           238             51     21
# 5          0.000000            4762           148             27      1
# 6          0.000000            5471            95             19     10
# ...             ...             ...           ...            ...    ...
# 9402       0.000000            5481            84             13      8
# 9423       0.000000            4752           324             44      7
# 9428       0.000000            1596           553             56     12
# 10453      0.000000             980           394             57     17
# 10736      0.000000            1676           389             42      5
#
#        current_value  highest_value  position_encoded  winger
# 0           15000000       70000000                 1       0
# 3           50000000       50000000                 2       0
# 4           40000000       80000000                 2       0
# 5           25000000       70000000                 2       0
# 6           15000000       35000000                 2       0
# ...              ...            ...               ...     ...
# 9402         4000000       30000000                 4       1
# 9423          800000       22000000                 3       0
# 9428         7000000       20000000                 3       0
# 10453         500000       36500000                 4       1
# 10736        1500000       30000000                 3       0
#
# [785 rows x 21 columns]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['appearance'], bins=40)                         
plt.xlabel('appearance  ')
plt.ylabel('Frequency')
plt.title('Histogram of appearance  ')
plt.show()

# %%
Q1 = df_pl['yellow cards'].quantile(0.25)
Q3 = df_pl['yellow cards'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['yellow cards'] >= Q1 - 1.5 * IQR) & (df_pl['yellow cards'] <= Q3 + 1.5 * IQR)]

# %%
Q1 = df_pl['second yellow cards'].quantile(0.25)
Q3 = df_pl['second yellow cards'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['second yellow cards'] >= Q1 - 1.5 * IQR) & (df_pl['second yellow cards'] <= Q3 + 1.5 * IQR)]

# %%
Q1 = df_pl['goals conceded'].quantile(0.25)
Q3 = df_pl['goals conceded'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['goals conceded'] >= Q1 - 1.5 * IQR) & (df_pl['goals conceded'] <= Q3 + 1.5 * IQR)]

# %%
Q1 = df_pl['clean sheets'].quantile(0.25)
Q3 = df_pl['clean sheets'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['clean sheets'] >= Q1 - 1.5 * IQR) & (df_pl['clean sheets'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['minutes played'], bins=40)                         
plt.xlabel('minutes played  ')
plt.ylabel('Frequency')
plt.title('Histogram of minutes played  ')
plt.show()

# %%
Q1 = df_pl['days_injured'].quantile(0.25)
Q3 = df_pl['days_injured'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['days_injured'] >= Q1 - 1.5 * IQR) & (df_pl['days_injured'] <= Q3 + 1.5 * IQR)]

# %%
Q1 = df_pl['games_injured'].quantile(0.25)
Q3 = df_pl['games_injured'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['games_injured'] >= Q1 - 1.5 * IQR) & (df_pl['games_injured'] <= Q3 + 1.5 * IQR)]

# %%
Q1 = df_pl['award'].quantile(0.25)
Q3 = df_pl['award'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['award'] >= Q1 - 1.5 * IQR) & (df_pl['award'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['award'], bins=40)                         
plt.xlabel('award')
plt.ylabel('Frequency')
plt.title('Histogram of minutes award')
plt.show()

# %%
Q1 = df_pl['position_encoded'].quantile(0.25)
Q3 = df_pl['position_encoded'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['position_encoded'] >= Q1 - 1.5 * IQR) & (df_pl['position_encoded'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['position_encoded'], bins=40)                         
plt.xlabel('position_encoded')
plt.ylabel('Frequency')
plt.title('Histogram of position_encoded')
plt.show()

# %%
df_pl
# Out:
#                            team                 name  \
# 3             Manchester United    Lisandro Martínez
# 6             Manchester United      Victor Lindelöf
# 9             Manchester United            Luke Shaw
# 10            Manchester United       Tyrell Malacia
# 12            Manchester United          Diogo Dalot
# ...                         ...                  ...
# 9398          Al-Hilal Saudi FC       Luciano Vietto
# 9402          Al-Hilal Saudi FC        Moussa Marega
# 9423                Al-Nassr FC         Luiz Gustavo
# 9428                Al-Nassr FC        Pity Martínez
# 10736  Western Sydney Wanderers  Morgan Schneiderlin
#
#                          position  height   age  appearance     goals  \
# 3            Defender Centre-Back   175.0  25.0          82  0.028090
# 6            Defender Centre-Back   187.0  28.0          70  0.000000
# 9              Defender Left-Back   178.0  27.0          74  0.015374
# 10             Defender Left-Back   169.0  23.0          89  0.012619
# 12            Defender Right-Back   183.0  24.0          72  0.032293
# ...                           ...     ...   ...         ...       ...
# 9398   midfield-AttackingMidfield   173.0  29.0          53  0.387417
# 9402           Attack-RightWinger   183.0  32.0          71  0.377668
# 9423   midfield-DefensiveMidfield   187.0  35.0          60  0.132576
# 9428   midfield-AttackingMidfield   170.0  29.0          29  0.451128
# 10736  midfield-DefensiveMidfield   186.0  33.0          36  0.107399
#
#         assists  yellow cards  second yellow cards  ...  goals conceded  \
# 3      0.056180      0.224719                  0.0  ...             0.0
# 6      0.032901      0.115153                  0.0  ...             0.0
# 9      0.169115      0.353604                  0.0  ...             0.0
# 10     0.063096      0.227145                  0.0  ...             0.0
# 12     0.048439      0.226050                  0.0  ...             0.0
# ...         ...           ...                  ...  ...             ...
# 9398   0.149007      0.119205                  0.0  ...             0.0
# 9402   0.098522      0.098522                  0.0  ...             0.0
# 9423   0.094697      0.189394                  0.0  ...             0.0
# 9428   0.112782      0.281955                  0.0  ...             0.0
# 10736  0.107399      0.268496                  0.0  ...             0.0
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 3               0.0            6408           175             22      9
# 6               0.0            5471            95             19     10
# 9               0.0            5854           443             70      4
# 10              0.0            7132           182             15      3
# 12              0.0            5574           328             49      3
# ...             ...             ...           ...            ...    ...
# 9398            0.0            3020           122             20      8
# 9402            0.0            5481            84             13      8
# 9423            0.0            4752           324             44      7
# 9428            0.0            1596           553             56     12
# 10736           0.0            1676           389             42      5
#
#        current_value  highest_value  position_encoded  winger
# 3           50000000       50000000                 2       0
# 6           15000000       35000000                 2       0
# 9           35000000       42000000                 2       1
# 10          22000000       22000000                 2       1
# 12          35000000       35000000                 2       1
# ...              ...            ...               ...     ...
# 9398         2500000       20000000                 3       0
# 9402         4000000       30000000                 4       1
# 9423          800000       22000000                 3       0
# 9428         7000000       20000000                 3       0
# 10736        1500000       30000000                 3       0
#
# [536 rows x 21 columns]

# %%
df_pl = pd.get_dummies(df_pl, columns=categorical_features)

# %%
df_pl.shape
# Out:
# (536, 679)

# %%
correlation = df_pl.corr()
print(correlation['current_value'].sort_values(ascending=False))
# Out:
# current_value          1.000000
# minutes played         0.430507
# appearance             0.395084
# highest_value          0.356068
# team_Arsenal FC        0.150335
#                          ...
# games_injured         -0.258939
# age                   -0.526666
# second yellow cards         NaN
# goals conceded              NaN
# clean sheets                NaN
# Name: current_value, Length: 679, dtype: float64

# %%
# Set the correlation threshold
threshold = 0.2  # You can change this value based on your requirement

# Filter the correlations
# We use `abs()` for absolute value to consider both strong positive and negative correlations
selected_features = correlation[abs(correlation['current_value']) > threshold]['current_value'].index
selected_features
# Out:
# Index(['age', 'appearance', 'minutes played', 'days_injured', 'games_injured',
#        'current_value', 'highest_value'],
#       dtype='object')

# %%
selected_features=['age', 'appearance', 'minutes played', 'days_injured', 'games_injured',
       'current_value', 'highest_value']

# %%
df_pl=df_pl[selected_features]
df_pl.head(2)
# Out:
#     age  appearance  minutes played  days_injured  games_injured  \
# 3  25.0          82            6408           175             22
# 6  28.0          70            5471            95             19
#
#    current_value  highest_value
# 3       50000000       50000000
# 6       15000000       35000000

# %%
X = df_pl.drop(['current_value'], axis=1)
y = df_pl['current_value']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=42)

# sacle the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X.shape
# Out:
# (536, 6)

# %%
model = LinearRegression()

# %%
ridge_model = Ridge()  # You can adjust alpha to see different resu

# %%
lasso_model = Lasso()  # You can adjust alpha to see different results

# %%
param_grid = {
    'alpha': [0, 0.0000003, 0.0002, 0.001, 0.01, 0.5, 1, 5]  # Regularization strength
}
grid_search = GridSearchCV(estimator=ridge_model,
                           param_grid=param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error', 
                           verbose=1)

grid_search_lasso = GridSearchCV(estimator=lasso_model,
                           param_grid=param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error', 
                           verbose=1)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# age            -6.724754e+06
# appearance      3.719621e+05
# minutes played  4.578384e+06
# days_injured    1.614761e+06
# games_injured  -1.053526e+06
# highest_value   4.769026e+06

# %%
print(model.intercept_)
# Out:
# 19049883.177570093

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
mse_base = mean_squared_error(y_test, y_base )
print(f'Mean Squared Error of base model: {mse_base}')
# Out:
# Mean Squared Error of base model: 142527139811155.28

# %%
mse_train = mean_squared_error(y_train, model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train}')
print(f'Mean Squared Error for testing: {mse_test}')
# Out:
# Mean Squared Error for training: 51510389313821.37
# Mean Squared Error for testing: 43544860570330.35

# %%
mse_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mse_base}')
# Out:
# Mean Absolute  Error of base model: 9869435.790931119

# %%
mae_train = mean_absolute_error(y_train, model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train}')
print(f'Mean Absolute Error for testing: {mae_test}')
# Out:
# Mean Absolute Error for training: 5585230.169181465
# Mean Absolute Error for testing: 5244354.13254937

# %%
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base)}')
# Out:
# Root Mean Squared  Error of base model: 3141.5658183350415

# %%
print(f'Root Mean Squared Error for training: {np.sqrt(mse_train)}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test)}')
# Out:
# Root Mean Squared Error for training: 7177073.868494135
# Root Mean Squared Error for testing: 6598852.97383798

# %%
r2_score_train = r2_score(y_train, model.predict(X_train_scaled))
r2_score_test = r2_score(y_test, y_pred)
print(f'R Square for training: {r2_score_train}')
print(f'R Square for testing: {r2_score_test}')
# Out:
# R Square for training: 0.6156031410623267
# R Square for testing: 0.6932730488153269

# %%
predictions = model.predict(X_test_scaled)

# %%
Real_Values = np.array(y_test)

# %%
plt.scatter(Real_Values,predictions);

# %%
sns.distplot((y_test-predictions),bins=50)
# Out:
# <Axes: xlabel='current_value', ylabel='Density'>
