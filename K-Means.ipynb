# %%
# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

from sklearn import metrics

# %matplotlib inline

# %%
df_pl=pd.read_csv('final_data.csv')

# %%
correlation = df_pl.corr(numeric_only=True)
print(correlation['current_value'].sort_values(ascending=False))
# Out:
# current_value          1.000000
# highest_value          0.834553
# minutes played         0.420542
# appearance             0.419656
# award                  0.300454
# assists                0.137415
# games_injured          0.135654
# goals                  0.121574
# days_injured           0.107686
# position_encoded       0.085154
# height                 0.040535
# winger                 0.005034
# red cards             -0.010171
# clean sheets          -0.011684
# yellow cards          -0.011766
# second yellow cards   -0.013889
# age                   -0.050156
# goals conceded        -0.063529
# Name: current_value, dtype: float64

# %%
df_pl
# Out:
#                                           player                      team  \
# 0             /david-de-gea/profil/spieler/59377         Manchester United
# 1            /jack-butland/profil/spieler/128899         Manchester United
# 2               /tom-heaton/profil/spieler/34130         Manchester United
# 3       /lisandro-martinez/profil/spieler/480762         Manchester United
# 4          /raphael-varane/profil/spieler/164770         Manchester United
# ...                                          ...                       ...
# 10749       /aidan-simmons/profil/spieler/867763  Western Sydney Wanderers
# 10750        /kusini-yengi/profil/spieler/708099  Western Sydney Wanderers
# 10751    /nathanael-blair/profil/spieler/1023268  Western Sydney Wanderers
# 10752    /zachary-sapsford/profil/spieler/703657  Western Sydney Wanderers
# 10753  /alexander-badolato/profil/spieler/957230  Western Sydney Wanderers
#
#                      name               position      height   age  \
# 0            David de Gea             Goalkeeper  189.000000  32.0
# 1            Jack Butland             Goalkeeper  196.000000  30.0
# 2              Tom Heaton             Goalkeeper  188.000000  37.0
# 3       Lisandro Martínez   Defender Centre-Back  175.000000  25.0
# 4          Raphaël Varane   Defender Centre-Back  191.000000  30.0
# ...                   ...                    ...         ...   ...
# 10749       Aidan Simmons     Attack-RightWinger  181.240353  20.0
# 10750        Kusini Yengi  Attack Centre-Forward  190.000000  24.0
# 10751     Nathanael Blair  Attack Centre-Forward  181.240353  19.0
# 10752    Zachary Sapsford  Attack Centre-Forward  181.240353  20.0
# 10753  Alexander Badolato  Attack Centre-Forward  170.000000  18.0
#
#        appearance     goals   assists  yellow cards  ...  goals conceded  \
# 0             104  0.000000  0.000000      0.009585  ...        1.217252
# 1              15  0.000000  0.000000      0.069018  ...        1.242331
# 2               4  0.000000  0.000000      0.000000  ...        0.616438
# 3              82  0.028090  0.056180      0.224719  ...        0.000000
# 4              63  0.017889  0.017889      0.053667  ...        0.000000
# ...           ...       ...       ...           ...  ...             ...
# 10749          16  0.175953  0.087977      0.263930  ...        0.000000
# 10750          26  0.372671  0.186335      0.186335  ...        0.000000
# 10751          20  0.375000  0.000000      0.187500  ...        0.000000
# 10752          17  0.312139  0.104046      0.000000  ...        0.000000
# 10753          21  0.000000  0.000000      0.086042  ...        0.000000
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 0          0.335463            9390            42              5     13
# 1          0.207055            1304           510             58      1
# 2          0.924658             292           697             84      4
# 3          0.000000            6408           175             22      9
# 4          0.000000            5031           238             51     21
# ...             ...             ...           ...            ...    ...
# 10749      0.000000            1023             0              0      0
# 10750      0.000000            1449           102             18      0
# 10751      0.000000             960             0              0      0
# 10752      0.000000             865             0              0      0
# 10753      0.000000            1046             0              0      0
#
#        current_value  highest_value  position_encoded  winger
# 0           15000000       70000000                 1       0
# 1            1500000       22000000                 1       0
# 2             600000        6000000                 1       0
# 3           50000000       50000000                 2       0
# 4           40000000       80000000                 2       0
# ...              ...            ...               ...     ...
# 10749          75000          75000                 4       1
# 10750         300000         300000                 4       0
# 10751          50000          50000                 4       0
# 10752          50000          50000                 4       0
# 10753          25000          25000                 4       0
#
# [10754 rows x 22 columns]

# %%
correlation = df_pl.corr(numeric_only=True)
print(correlation['current_value'].sort_values(ascending=False))
# Out:
# current_value          1.000000
# highest_value          0.834553
# minutes played         0.420542
# appearance             0.419656
# award                  0.300454
# assists                0.137415
# games_injured          0.135654
# goals                  0.121574
# days_injured           0.107686
# position_encoded       0.085154
# height                 0.040535
# winger                 0.005034
# red cards             -0.010171
# clean sheets          -0.011684
# yellow cards          -0.011766
# second yellow cards   -0.013889
# age                   -0.050156
# goals conceded        -0.063529
# Name: current_value, dtype: float64

# %%
df_pl.duplicated().sum()
# Out:
# 0

# %%
df_pl.isnull().sum()
# Out:
# player                 0
# team                   0
# name                   0
# position               0
# height                 0
# age                    0
# appearance             0
# goals                  0
# assists                0
# yellow cards           0
# second yellow cards    0
# red cards              0
# goals conceded         0
# clean sheets           0
# minutes played         0
# days_injured           0
# games_injured          0
# award                  0
# current_value          0
# highest_value          0
# position_encoded       0
# winger                 0
# dtype: int64

# %%
df_pl.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
df_pl=df_pl.drop(['player'], axis=1)

# %%
df_pl.head(2)
# Out:
#                 team          name    position  height   age  appearance  \
# 0  Manchester United  David de Gea  Goalkeeper   189.0  32.0         104
# 1  Manchester United  Jack Butland  Goalkeeper   196.0  30.0          15
#
#    goals  assists  yellow cards  second yellow cards  ...  goals conceded  \
# 0    0.0      0.0      0.009585                  0.0  ...        1.217252
# 1    0.0      0.0      0.069018                  0.0  ...        1.242331
#
#    clean sheets  minutes played  days_injured  games_injured  award  \
# 0      0.335463            9390            42              5     13
# 1      0.207055            1304           510             58      1
#
#    current_value  highest_value  position_encoded  winger
# 0       15000000       70000000                 1       0
# 1        1500000       22000000                 1       0
#
# [2 rows x 21 columns]

# %%
df_pl.sort_values(by='highest_value' , ascending=False).head()
# Out:
#                      team             name               position  height  \
# 2644  Paris Saint-Germain    Kylian Mbappé  Attack Centre-Forward   178.0
# 2643  Paris Saint-Germain     Lionel Messi     Attack-RightWinger   170.0
# 2642  Paris Saint-Germain           Neymar      Attack-LeftWinger   175.0
# 453       Manchester City   Erling Haaland  Attack Centre-Forward   195.0
# 527            Chelsea FC  Raheem Sterling      Attack-LeftWinger   170.0
#
#        age  appearance     goals   assists  yellow cards  second yellow cards  \
# 2644  24.0          89  0.963082  0.433387      0.204655              0.00000
# 2643  35.0          75  0.442464  0.483945      0.013827              0.00000
# 2642  31.0          57  0.594883  0.479744      0.383795              0.01919
# 453   22.0          83  1.118270  0.234699      0.124252              0.00000
# 527   28.0          85  0.414233  0.207116      0.111524              0.00000
#
#       ...  goals conceded  clean sheets  minutes played  days_injured  \
# 2644  ...             0.0           0.0            7476           139
# 2643  ...             0.0           0.0            6509           167
# 2642  ...             0.0           0.0            4690           419
# 453   ...             0.0           0.0            6519           204
# 527   ...             0.0           0.0            5649           284
#
#       games_injured  award  current_value  highest_value  position_encoded  \
# 2644             23     37      180000000      200000000                 4
# 2643             30     92       45000000      180000000                 4
# 2642             67     35       70000000      180000000                 4
# 453              36     17      170000000      170000000                 4
# 527              34     13       60000000      160000000                 4
#
#       winger
# 2644       0
# 2643       1
# 2642       1
# 453        0
# 527        1
#
# [5 rows x 21 columns]

# %%
df_pl.dtypes
# Out:
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
categorical_features=['team','name','position']
numeric_features=['position',  'height',  'age' , 'appearance' ,'goals',  'assists',  'yellow', 'cards', 'second', 'yellow cards',
 'red cards',  'goals conceded' ,'clean sheet', 'minutes played' ,'days_injured',  'games_injured'  , 'award' ,'current_value',
 'highest_value' , 'position_encoded' ,'winger' ]

# %%
Q1 = df_pl['highest_value'].quantile(0.25)
Q3 = df_pl['highest_value'].quantile(0.75)
IQR = Q3 - Q1
df_pl2 = df_pl[(df_pl['highest_value'] >= Q1 - 1.5 * IQR) & (df_pl['highest_value'] <= Q3 + 1.5 * IQR)]

df_pl2
# Out:
#                            team                name                  position  \
# 2             Manchester United          Tom Heaton                Goalkeeper
# 8             Manchester United         Teden Mengi      Defender Centre-Back
# 20            Manchester United        Zidane Iqbal  midfield-CentralMidfield
# 21            Manchester United       Kobbie Mainoo  midfield-CentralMidfield
# 28            Manchester United   Facundo Pellistri        Attack-RightWinger
# ...                         ...                 ...                       ...
# 10749  Western Sydney Wanderers       Aidan Simmons        Attack-RightWinger
# 10750  Western Sydney Wanderers        Kusini Yengi     Attack Centre-Forward
# 10751  Western Sydney Wanderers     Nathanael Blair     Attack Centre-Forward
# 10752  Western Sydney Wanderers    Zachary Sapsford     Attack Centre-Forward
# 10753  Western Sydney Wanderers  Alexander Badolato     Attack Centre-Forward
#
#            height   age  appearance     goals   assists  yellow cards  \
# 2      188.000000  37.0           4  0.000000  0.000000      0.000000
# 8      186.000000  21.0          34  0.000000  0.000000      0.130529
# 20     181.000000  20.0          39  0.129125  0.064562      0.225968
# 21     175.000000  18.0          51  0.153759  0.102506      0.000000
# 28     174.000000  21.0          34  0.000000  0.087379      0.262136
# ...           ...   ...         ...       ...       ...           ...
# 10749  181.240353  20.0          16  0.175953  0.087977      0.263930
# 10750  190.000000  24.0          26  0.372671  0.186335      0.186335
# 10751  181.240353  19.0          20  0.375000  0.000000      0.187500
# 10752  181.240353  20.0          17  0.312139  0.104046      0.000000
# 10753  170.000000  18.0          21  0.000000  0.000000      0.086042
#
#        second yellow cards  ...  goals conceded  clean sheets  minutes played  \
# 2                      0.0  ...        0.616438      0.924658             292
# 8                      0.0  ...        0.000000      0.000000            2758
# 20                     0.0  ...        0.000000      0.000000            2788
# 21                     0.0  ...        0.000000      0.000000            3512
# 28                     0.0  ...        0.000000      0.000000            1030
# ...                    ...  ...             ...           ...             ...
# 10749                  0.0  ...        0.000000      0.000000            1023
# 10750                  0.0  ...        0.000000      0.000000            1449
# 10751                  0.0  ...        0.000000      0.000000             960
# 10752                  0.0  ...        0.000000      0.000000             865
# 10753                  0.0  ...        0.000000      0.000000            1046
#
#        days_injured  games_injured  award  current_value  highest_value  \
# 2               697             84      4         600000        6000000
# 8                47             13      0        2000000        2000000
# 20                0              0      1         800000         800000
# 21                0              0      1         800000         800000
# 28               90             15      1        3000000        7000000
# ...             ...            ...    ...            ...            ...
# 10749             0              0      0          75000          75000
# 10750           102             18      0         300000         300000
# 10751             0              0      0          50000          50000
# 10752             0              0      0          50000          50000
# 10753             0              0      0          25000          25000
#
#        position_encoded  winger
# 2                     1       0
# 8                     2       0
# 20                    3       0
# 21                    3       0
# 28                    4       1
# ...                 ...     ...
# 10749                 4       1
# 10750                 4       0
# 10751                 4       0
# 10752                 4       0
# 10753                 4       0
#
# [9219 rows x 21 columns]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl2['highest_value'], bins=40)                         
plt.xlabel('Highest Value')
plt.ylabel('Frequency')
plt.title('Histogram of Highest Values')
plt.show()

# %%
Q1 = df_pl['highest_value'].quantile(0.25)
Q3 = df_pl['highest_value'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['highest_value'] >= Q1 - 1.5 * IQR) & (df_pl['highest_value'] <= Q3 + 1.5 * IQR)]

# %%
df_pl.sort_values(by='highest_value' , ascending=False).head()
# Out:
#                     team                name                    position  \
# 2654          AZ Alkmaar  Bruno Martins Indi        Defender Centre-Back
# 1878       Hellas Verona       Miguel Veloso  midfield-DefensiveMidfield
# 1373  Real Valladolid CF          Cyle Larin       Attack Centre-Forward
# 6294          Fenerbahce   Irfan Can Kahveci          Attack-RightWinger
# 1829            US Lecce          Rémi Oudin          Attack-RightWinger
#
#       height   age  appearance     goals   assists  yellow cards  \
# 2654   185.0  31.0          59  0.034377  0.017189      0.137510
# 1878   181.0  37.0          46  0.000000  0.134882      0.370925
# 1373   188.0  28.0          70  0.366292  0.086186      0.237012
# 6294   176.0  27.0          71  0.230340  0.272220      0.314100
# 1829   183.0  26.0          64  0.206557  0.147541      0.236066
#
#       second yellow cards  ...  goals conceded  clean sheets  minutes played  \
# 2654              0.00000  ...             0.0           0.0            5236
# 1878              0.03372  ...             0.0           0.0            2669
# 1373              0.00000  ...             0.0           0.0            4177
# 6294              0.00000  ...             0.0           0.0            4298
# 1829              0.00000  ...             0.0           0.0            3050
#
#       days_injured  games_injured  award  current_value  highest_value  \
# 2654           425             67      1        2200000       11500000
# 1878           444             68      9         700000       11500000
# 1373            85             10      5        8000000       11500000
# 6294           212             44      2        6500000       11500000
# 1829             0              0      0        4000000       11000000
#
#       position_encoded  winger
# 2654                 2       0
# 1878                 3       0
# 1373                 4       0
# 6294                 4       1
# 1829                 4       1
#
# [5 rows x 21 columns]

# %%
Q1 = df_pl['goals'].quantile(0.25)
Q3 = df_pl['goals'].quantile(0.75)
IQR = Q3 - Q1
df_pl2 = df_pl[(df_pl['goals'] >= Q1 - 1.5 * IQR) & (df_pl['goals'] <= Q3 + 1.5 * IQR)]

df_pl2
# Out:
#                            team                name                  position  \
# 2             Manchester United          Tom Heaton                Goalkeeper
# 8             Manchester United         Teden Mengi      Defender Centre-Back
# 20            Manchester United        Zidane Iqbal  midfield-CentralMidfield
# 21            Manchester United       Kobbie Mainoo  midfield-CentralMidfield
# 28            Manchester United   Facundo Pellistri        Attack-RightWinger
# ...                         ...                 ...                       ...
# 10749  Western Sydney Wanderers       Aidan Simmons        Attack-RightWinger
# 10750  Western Sydney Wanderers        Kusini Yengi     Attack Centre-Forward
# 10751  Western Sydney Wanderers     Nathanael Blair     Attack Centre-Forward
# 10752  Western Sydney Wanderers    Zachary Sapsford     Attack Centre-Forward
# 10753  Western Sydney Wanderers  Alexander Badolato     Attack Centre-Forward
#
#            height   age  appearance     goals   assists  yellow cards  \
# 2      188.000000  37.0           4  0.000000  0.000000      0.000000
# 8      186.000000  21.0          34  0.000000  0.000000      0.130529
# 20     181.000000  20.0          39  0.129125  0.064562      0.225968
# 21     175.000000  18.0          51  0.153759  0.102506      0.000000
# 28     174.000000  21.0          34  0.000000  0.087379      0.262136
# ...           ...   ...         ...       ...       ...           ...
# 10749  181.240353  20.0          16  0.175953  0.087977      0.263930
# 10750  190.000000  24.0          26  0.372671  0.186335      0.186335
# 10751  181.240353  19.0          20  0.375000  0.000000      0.187500
# 10752  181.240353  20.0          17  0.312139  0.104046      0.000000
# 10753  170.000000  18.0          21  0.000000  0.000000      0.086042
#
#        second yellow cards  ...  goals conceded  clean sheets  minutes played  \
# 2                      0.0  ...        0.616438      0.924658             292
# 8                      0.0  ...        0.000000      0.000000            2758
# 20                     0.0  ...        0.000000      0.000000            2788
# 21                     0.0  ...        0.000000      0.000000            3512
# 28                     0.0  ...        0.000000      0.000000            1030
# ...                    ...  ...             ...           ...             ...
# 10749                  0.0  ...        0.000000      0.000000            1023
# 10750                  0.0  ...        0.000000      0.000000            1449
# 10751                  0.0  ...        0.000000      0.000000             960
# 10752                  0.0  ...        0.000000      0.000000             865
# 10753                  0.0  ...        0.000000      0.000000            1046
#
#        days_injured  games_injured  award  current_value  highest_value  \
# 2               697             84      4         600000        6000000
# 8                47             13      0        2000000        2000000
# 20                0              0      1         800000         800000
# 21                0              0      1         800000         800000
# 28               90             15      1        3000000        7000000
# ...             ...            ...    ...            ...            ...
# 10749             0              0      0          75000          75000
# 10750           102             18      0         300000         300000
# 10751             0              0      0          50000          50000
# 10752             0              0      0          50000          50000
# 10753             0              0      0          25000          25000
#
#        position_encoded  winger
# 2                     1       0
# 8                     2       0
# 20                    3       0
# 21                    3       0
# 28                    4       1
# ...                 ...     ...
# 10749                 4       1
# 10750                 4       0
# 10751                 4       0
# 10752                 4       0
# 10753                 4       0
#
# [8468 rows x 21 columns]

# %%
Q1 = df_pl['goals'].quantile(0.25)
Q3 = df_pl['goals'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['goals'] >= Q1 - 1.5 * IQR) & (df_pl['goals'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['goals'], bins=40)                         
plt.xlabel('goals')
plt.ylabel('Frequency')
plt.title('Histogram of goals')
plt.show()

# %%
df_pl['current_value'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 2         600000
# 8        2000000
# 20        800000
# 21        800000
# 28       3000000
#           ...
# 10749      75000
# 10750     300000
# 10751      50000
# 10752      50000
# 10753      25000
# Name: current_value, Length: 8468, dtype: int64>

# %%
Q1 = df_pl['current_value'].quantile(0.25)
Q3 = df_pl['current_value'].quantile(0.75)
IQR = Q3 - Q1
df_pl3=df_pl[(df_pl['current_value'] >= Q1 - 1.5 * IQR) & (df_pl['current_value'] <= Q3 + 1.5 * IQR)]
df_pl3
# Out:
#                            team                name                  position  \
# 2             Manchester United          Tom Heaton                Goalkeeper
# 8             Manchester United         Teden Mengi      Defender Centre-Back
# 20            Manchester United        Zidane Iqbal  midfield-CentralMidfield
# 21            Manchester United       Kobbie Mainoo  midfield-CentralMidfield
# 28            Manchester United   Facundo Pellistri        Attack-RightWinger
# ...                         ...                 ...                       ...
# 10749  Western Sydney Wanderers       Aidan Simmons        Attack-RightWinger
# 10750  Western Sydney Wanderers        Kusini Yengi     Attack Centre-Forward
# 10751  Western Sydney Wanderers     Nathanael Blair     Attack Centre-Forward
# 10752  Western Sydney Wanderers    Zachary Sapsford     Attack Centre-Forward
# 10753  Western Sydney Wanderers  Alexander Badolato     Attack Centre-Forward
#
#            height   age  appearance     goals   assists  yellow cards  \
# 2      188.000000  37.0           4  0.000000  0.000000      0.000000
# 8      186.000000  21.0          34  0.000000  0.000000      0.130529
# 20     181.000000  20.0          39  0.129125  0.064562      0.225968
# 21     175.000000  18.0          51  0.153759  0.102506      0.000000
# 28     174.000000  21.0          34  0.000000  0.087379      0.262136
# ...           ...   ...         ...       ...       ...           ...
# 10749  181.240353  20.0          16  0.175953  0.087977      0.263930
# 10750  190.000000  24.0          26  0.372671  0.186335      0.186335
# 10751  181.240353  19.0          20  0.375000  0.000000      0.187500
# 10752  181.240353  20.0          17  0.312139  0.104046      0.000000
# 10753  170.000000  18.0          21  0.000000  0.000000      0.086042
#
#        second yellow cards  ...  goals conceded  clean sheets  minutes played  \
# 2                      0.0  ...        0.616438      0.924658             292
# 8                      0.0  ...        0.000000      0.000000            2758
# 20                     0.0  ...        0.000000      0.000000            2788
# 21                     0.0  ...        0.000000      0.000000            3512
# 28                     0.0  ...        0.000000      0.000000            1030
# ...                    ...  ...             ...           ...             ...
# 10749                  0.0  ...        0.000000      0.000000            1023
# 10750                  0.0  ...        0.000000      0.000000            1449
# 10751                  0.0  ...        0.000000      0.000000             960
# 10752                  0.0  ...        0.000000      0.000000             865
# 10753                  0.0  ...        0.000000      0.000000            1046
#
#        days_injured  games_injured  award  current_value  highest_value  \
# 2               697             84      4         600000        6000000
# 8                47             13      0        2000000        2000000
# 20                0              0      1         800000         800000
# 21                0              0      1         800000         800000
# 28               90             15      1        3000000        7000000
# ...             ...            ...    ...            ...            ...
# 10749             0              0      0          75000          75000
# 10750           102             18      0         300000         300000
# 10751             0              0      0          50000          50000
# 10752             0              0      0          50000          50000
# 10753             0              0      0          25000          25000
#
#        position_encoded  winger
# 2                     1       0
# 8                     2       0
# 20                    3       0
# 21                    3       0
# 28                    4       1
# ...                 ...     ...
# 10749                 4       1
# 10750                 4       0
# 10751                 4       0
# 10752                 4       0
# 10753                 4       0
#
# [7537 rows x 21 columns]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['current_value'], bins=40)                         
plt.xlabel('current_value')
plt.ylabel('Frequency')
plt.title('Histogram of current_value')
plt.show()

# %%
Q1 = df_pl['current_value'].quantile(0.25)
Q3 = df_pl['current_value'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['current_value'] >= Q1 - 1.5 * IQR) & (df_pl['current_value'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['assists'], bins=40)                         
plt.xlabel('assists  ')
plt.ylabel('Frequency')
plt.title('Histogram of assists  ')
plt.show()

# %%
Q1 = df_pl['assists'].quantile(0.25)
Q3 = df_pl['assists'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['assists'] >= Q1 - 1.5 * IQR) & (df_pl['assists'] <= Q3 + 1.5 * IQR)]

# %%
df_pl
# Out:
#                            team                name                  position  \
# 2             Manchester United          Tom Heaton                Goalkeeper
# 8             Manchester United         Teden Mengi      Defender Centre-Back
# 20            Manchester United        Zidane Iqbal  midfield-CentralMidfield
# 21            Manchester United       Kobbie Mainoo  midfield-CentralMidfield
# 28            Manchester United   Facundo Pellistri        Attack-RightWinger
# ...                         ...                 ...                       ...
# 10749  Western Sydney Wanderers       Aidan Simmons        Attack-RightWinger
# 10750  Western Sydney Wanderers        Kusini Yengi     Attack Centre-Forward
# 10751  Western Sydney Wanderers     Nathanael Blair     Attack Centre-Forward
# 10752  Western Sydney Wanderers    Zachary Sapsford     Attack Centre-Forward
# 10753  Western Sydney Wanderers  Alexander Badolato     Attack Centre-Forward
#
#            height   age  appearance     goals   assists  yellow cards  \
# 2      188.000000  37.0           4  0.000000  0.000000      0.000000
# 8      186.000000  21.0          34  0.000000  0.000000      0.130529
# 20     181.000000  20.0          39  0.129125  0.064562      0.225968
# 21     175.000000  18.0          51  0.153759  0.102506      0.000000
# 28     174.000000  21.0          34  0.000000  0.087379      0.262136
# ...           ...   ...         ...       ...       ...           ...
# 10749  181.240353  20.0          16  0.175953  0.087977      0.263930
# 10750  190.000000  24.0          26  0.372671  0.186335      0.186335
# 10751  181.240353  19.0          20  0.375000  0.000000      0.187500
# 10752  181.240353  20.0          17  0.312139  0.104046      0.000000
# 10753  170.000000  18.0          21  0.000000  0.000000      0.086042
#
#        second yellow cards  ...  goals conceded  clean sheets  minutes played  \
# 2                      0.0  ...        0.616438      0.924658             292
# 8                      0.0  ...        0.000000      0.000000            2758
# 20                     0.0  ...        0.000000      0.000000            2788
# 21                     0.0  ...        0.000000      0.000000            3512
# 28                     0.0  ...        0.000000      0.000000            1030
# ...                    ...  ...             ...           ...             ...
# 10749                  0.0  ...        0.000000      0.000000            1023
# 10750                  0.0  ...        0.000000      0.000000            1449
# 10751                  0.0  ...        0.000000      0.000000             960
# 10752                  0.0  ...        0.000000      0.000000             865
# 10753                  0.0  ...        0.000000      0.000000            1046
#
#        days_injured  games_injured  award  current_value  highest_value  \
# 2               697             84      4         600000        6000000
# 8                47             13      0        2000000        2000000
# 20                0              0      1         800000         800000
# 21                0              0      1         800000         800000
# 28               90             15      1        3000000        7000000
# ...             ...            ...    ...            ...            ...
# 10749             0              0      0          75000          75000
# 10750           102             18      0         300000         300000
# 10751             0              0      0          50000          50000
# 10752             0              0      0          50000          50000
# 10753             0              0      0          25000          25000
#
#        position_encoded  winger
# 2                     1       0
# 8                     2       0
# 20                    3       0
# 21                    3       0
# 28                    4       1
# ...                 ...     ...
# 10749                 4       1
# 10750                 4       0
# 10751                 4       0
# 10752                 4       0
# 10753                 4       0
#
# [7131 rows x 21 columns]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['assists'], bins=40)                         
plt.xlabel('assists  ')
plt.ylabel('Frequency')
plt.title('Histogram of assists  ')
plt.show()

# %%
Q1 = df_pl['height'].quantile(0.25)
Q3 = df_pl['height'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['height'] >= Q1 - 1.5 * IQR) & (df_pl['height'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['height'], bins=40)                         
plt.xlabel('height  ')
plt.ylabel('Frequency')
plt.title('Histogram of height  ')
plt.show()

# %%
Q1 = df_pl['appearance'].quantile(0.25)
Q3 = df_pl['appearance'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['appearance'] >= Q1 - 1.5 * IQR) & (df_pl['appearance'] <= Q3 + 1.5 * IQR)]

# %%
df_pl
# Out:
#                            team                name                  position  \
# 2             Manchester United          Tom Heaton                Goalkeeper
# 8             Manchester United         Teden Mengi      Defender Centre-Back
# 20            Manchester United        Zidane Iqbal  midfield-CentralMidfield
# 21            Manchester United       Kobbie Mainoo  midfield-CentralMidfield
# 28            Manchester United   Facundo Pellistri        Attack-RightWinger
# ...                         ...                 ...                       ...
# 10749  Western Sydney Wanderers       Aidan Simmons        Attack-RightWinger
# 10750  Western Sydney Wanderers        Kusini Yengi     Attack Centre-Forward
# 10751  Western Sydney Wanderers     Nathanael Blair     Attack Centre-Forward
# 10752  Western Sydney Wanderers    Zachary Sapsford     Attack Centre-Forward
# 10753  Western Sydney Wanderers  Alexander Badolato     Attack Centre-Forward
#
#            height   age  appearance     goals   assists  yellow cards  \
# 2      188.000000  37.0           4  0.000000  0.000000      0.000000
# 8      186.000000  21.0          34  0.000000  0.000000      0.130529
# 20     181.000000  20.0          39  0.129125  0.064562      0.225968
# 21     175.000000  18.0          51  0.153759  0.102506      0.000000
# 28     174.000000  21.0          34  0.000000  0.087379      0.262136
# ...           ...   ...         ...       ...       ...           ...
# 10749  181.240353  20.0          16  0.175953  0.087977      0.263930
# 10750  190.000000  24.0          26  0.372671  0.186335      0.186335
# 10751  181.240353  19.0          20  0.375000  0.000000      0.187500
# 10752  181.240353  20.0          17  0.312139  0.104046      0.000000
# 10753  170.000000  18.0          21  0.000000  0.000000      0.086042
#
#        second yellow cards  ...  goals conceded  clean sheets  minutes played  \
# 2                      0.0  ...        0.616438      0.924658             292
# 8                      0.0  ...        0.000000      0.000000            2758
# 20                     0.0  ...        0.000000      0.000000            2788
# 21                     0.0  ...        0.000000      0.000000            3512
# 28                     0.0  ...        0.000000      0.000000            1030
# ...                    ...  ...             ...           ...             ...
# 10749                  0.0  ...        0.000000      0.000000            1023
# 10750                  0.0  ...        0.000000      0.000000            1449
# 10751                  0.0  ...        0.000000      0.000000             960
# 10752                  0.0  ...        0.000000      0.000000             865
# 10753                  0.0  ...        0.000000      0.000000            1046
#
#        days_injured  games_injured  award  current_value  highest_value  \
# 2               697             84      4         600000        6000000
# 8                47             13      0        2000000        2000000
# 20                0              0      1         800000         800000
# 21                0              0      1         800000         800000
# 28               90             15      1        3000000        7000000
# ...             ...            ...    ...            ...            ...
# 10749             0              0      0          75000          75000
# 10750           102             18      0         300000         300000
# 10751             0              0      0          50000          50000
# 10752             0              0      0          50000          50000
# 10753             0              0      0          25000          25000
#
#        position_encoded  winger
# 2                     1       0
# 8                     2       0
# 20                    3       0
# 21                    3       0
# 28                    4       1
# ...                 ...     ...
# 10749                 4       1
# 10750                 4       0
# 10751                 4       0
# 10752                 4       0
# 10753                 4       0
#
# [7112 rows x 21 columns]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['appearance'], bins=40)                         
plt.xlabel('appearance  ')
plt.ylabel('Frequency')
plt.title('Histogram of appearance  ')
plt.show()

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['minutes played'], bins=40)                         
plt.xlabel('minutes played  ')
plt.ylabel('Frequency')
plt.title('Histogram of minutes played  ')
plt.show()

# %%
Q1 = df_pl['days_injured'].quantile(0.25)
Q3 = df_pl['days_injured'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['days_injured'] >= Q1 - 1.5 * IQR) & (df_pl['days_injured'] <= Q3 + 1.5 * IQR)]

# %%
Q1 = df_pl['games_injured'].quantile(0.25)
Q3 = df_pl['games_injured'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['games_injured'] >= Q1 - 1.5 * IQR) & (df_pl['games_injured'] <= Q3 + 1.5 * IQR)]

# %%
Q1 = df_pl['award'].quantile(0.25)
Q3 = df_pl['award'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['award'] >= Q1 - 1.5 * IQR) & (df_pl['award'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['award'], bins=40)                         
plt.xlabel('award')
plt.ylabel('Frequency')
plt.title('Histogram of minutes award')
plt.show()

# %%
Q1 = df_pl['position_encoded'].quantile(0.25)
Q3 = df_pl['position_encoded'].quantile(0.75)
IQR = Q3 - Q1
df_pl=df_pl[(df_pl['position_encoded'] >= Q1 - 1.5 * IQR) & (df_pl['position_encoded'] <= Q3 + 1.5 * IQR)]

# %%
plt.figure(figsize=(15,8))

plt.hist(df_pl['position_encoded'], bins=40)                         
plt.xlabel('position_encoded')
plt.ylabel('Frequency')
plt.title('Histogram of position_encoded')
plt.show()

# %%
df_pl
# Out:
#                            team                name                  position  \
# 8             Manchester United         Teden Mengi      Defender Centre-Back
# 20            Manchester United        Zidane Iqbal  midfield-CentralMidfield
# 21            Manchester United       Kobbie Mainoo  midfield-CentralMidfield
# 28            Manchester United   Facundo Pellistri        Attack-RightWinger
# 55               Leicester City      Daniel Iversen                Goalkeeper
# ...                         ...                 ...                       ...
# 10749  Western Sydney Wanderers       Aidan Simmons        Attack-RightWinger
# 10750  Western Sydney Wanderers        Kusini Yengi     Attack Centre-Forward
# 10751  Western Sydney Wanderers     Nathanael Blair     Attack Centre-Forward
# 10752  Western Sydney Wanderers    Zachary Sapsford     Attack Centre-Forward
# 10753  Western Sydney Wanderers  Alexander Badolato     Attack Centre-Forward
#
#            height   age  appearance     goals   assists  yellow cards  \
# 8      186.000000  21.0          34  0.000000  0.000000      0.130529
# 20     181.000000  20.0          39  0.129125  0.064562      0.225968
# 21     175.000000  18.0          51  0.153759  0.102506      0.000000
# 28     174.000000  21.0          34  0.000000  0.087379      0.262136
# 55     191.000000  25.0          65  0.000000  0.000000      0.015340
# ...           ...   ...         ...       ...       ...           ...
# 10749  181.240353  20.0          16  0.175953  0.087977      0.263930
# 10750  190.000000  24.0          26  0.372671  0.186335      0.186335
# 10751  181.240353  19.0          20  0.375000  0.000000      0.187500
# 10752  181.240353  20.0          17  0.312139  0.104046      0.000000
# 10753  170.000000  18.0          21  0.000000  0.000000      0.086042
#
#        second yellow cards  ...  goals conceded  clean sheets  minutes played  \
# 8                      0.0  ...        0.000000      0.000000            2758
# 20                     0.0  ...        0.000000      0.000000            2788
# 21                     0.0  ...        0.000000      0.000000            3512
# 28                     0.0  ...        0.000000      0.000000            1030
# 55                     0.0  ...        1.257883      0.291461            5867
# ...                    ...  ...             ...           ...             ...
# 10749                  0.0  ...        0.000000      0.000000            1023
# 10750                  0.0  ...        0.000000      0.000000            1449
# 10751                  0.0  ...        0.000000      0.000000             960
# 10752                  0.0  ...        0.000000      0.000000             865
# 10753                  0.0  ...        0.000000      0.000000            1046
#
#        days_injured  games_injured  award  current_value  highest_value  \
# 8                47             13      0        2000000        2000000
# 20                0              0      1         800000         800000
# 21                0              0      1         800000         800000
# 28               90             15      1        3000000        7000000
# 55                0              0      0        2000000        2000000
# ...             ...            ...    ...            ...            ...
# 10749             0              0      0          75000          75000
# 10750           102             18      0         300000         300000
# 10751             0              0      0          50000          50000
# 10752             0              0      0          50000          50000
# 10753             0              0      0          25000          25000
#
#        position_encoded  winger
# 8                     2       0
# 20                    3       0
# 21                    3       0
# 28                    4       1
# 55                    1       0
# ...                 ...     ...
# 10749                 4       1
# 10750                 4       0
# 10751                 4       0
# 10752                 4       0
# 10753                 4       0
#
# [5228 rows x 21 columns]

# %%
categorical_features
# Out:
# ['team', 'name', 'position']

# %%
correlation = df_pl.corr(numeric_only=True)
print(correlation['current_value'].sort_values(ascending=False))
# Out:
# current_value     1.000000
# highest_value     0.706182
# kmeans            0.672055
# appearance        0.404469
# minutes played    0.385717
# Name: current_value, dtype: float64

# %%
threshold = 0.1

selected_features = correlation[abs(correlation['current_value']) > threshold]['current_value'].index
selected_features
# Out:
# Index(['appearance', 'goals', 'assists', 'goals conceded', 'minutes played',
#        'days_injured', 'games_injured', 'award', 'current_value',
#        'highest_value'],
#       dtype='object')

# %%
selected_features=['appearance', 'minutes played', 'highest_value', 'current_value']

# %%
df_pl = df_pl[selected_features]
df_pl.head()
# Out:
#     appearance  minutes played  highest_value  current_value
# 8           34            2758        2000000        2000000
# 20          39            2788         800000         800000
# 21          51            3512         800000         800000
# 28          34            1030        7000000        3000000
# 55          65            5867        2000000        2000000

# %%
X = df_pl


# sacle the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X.shape
# Out:
# (5228, 4)

# %%
wcss = []
for i in range(1, 20):  # Test 1 to 10 clusters
    kmeans = KMeans(n_clusters=i,
                    init='k-means++',
                    max_iter=300,
                    n_init=10,
                    random_state=0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)  # inertia_ is the WCSS

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, 20), wcss,  marker='o', linestyle='-', color='b')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
# Optional: Apply k-Means using the optimal number of clusters
optimal_clusters = 5 # This might change based on your actual elbow curve analysis
model = KMeans(n_clusters=optimal_clusters, init='k-means++', max_iter=300, n_init=10, random_state=0)

# %%
y_pred = model.fit_predict(X_scaled)

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y_pred, s=50, cmap='viridis')

centers = model.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='X')
plt.title(f'K-Means Clustering with {optimal_clusters} Clusters')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
X['kmeans'] = y_pred

# %%
X['kmeans'].value_counts()
# Out:
# kmeans
# 1    2645
# 0    1431
# 4     510
# 2     495
# 3     147
# Name: count, dtype: int64

# %%
X[X['kmeans']==0]
# Out:
#        appearance  minutes played  highest_value  current_value  kmeans
# 20             39            2788         800000         800000       0
# 21             51            3512         800000         800000       0
# 106            60            5490         200000         200000       0
# 118            38            2424         500000         500000       0
# 163            25            2250        1500000        1000000       0
# ...           ...             ...            ...            ...     ...
# 10734          42            3315         400000         400000       0
# 10737          29            2432         400000         400000       0
# 10740          44            3585        2000000         500000       0
# 10741          33            2375         750000         350000       0
# 10747          35            2160        3000000         500000       0
#
# [1431 rows x 5 columns]

# %%
sns.scatterplot(data = X , x = 'current_value', y = 'minutes played', hue = 'kmeans')
# Out:
# <Axes: xlabel='current_value', ylabel='minutes played'>
